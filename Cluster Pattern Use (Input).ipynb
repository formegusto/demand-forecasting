# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import matplotlib.pyplot as plt
import pandas as pd
from src.model import BasicModel

plt.rcParams['figure.figsize'] = 15.7,13.27
plt.rcParams['font.family'] = 'AppleGothic'

class LEARN_INFO:
    def __init__(self, name, columns, is_contain_cluster_label=False):
        self.name = name
        self.columns = columns
        self.is_label = is_contain_cluster_label
    

# INPUT_REPORT_SIMULATION = [
#     LEARN_INFO(name="univariate", columns=['energy (kw 15min)'], is_contain_cluster_label=False),
#     LEARN_INFO(name="with cluster label", columns=['energy (kw 15min)'], is_contain_cluster_label=True),
# ]

DEFAULT_COLUMNS = [
    'energy (kw 15min)',
    ['week sin',
    'week cos'],
    ['year sin',
    'year cos'],
    'season idx',
    'weather idx',
    'avg ta',
    'avg rhm'
]

# %%
_ = {
    "univariate": ['energy (kw 15min)'],
    "multivariate (week)": [
        'energy (kw 15min)',
        'week sin',
        'week cos'
    ],
    "multivariate (year)": [
        'energy (kw 15min)',
        'year sin',
        'year cos',
    ],
    "multivariate (weather)": [
        'energy (kw 15min)',
        'weather idx'
    ],
    "multivariate (avg ta)": [
        'energy (kw 15min)',
        'avg ta'
    ],
    "multivariate (avg rhm)": [
        'energy (kw 15min)',
        'avg rhm'
    ],
    "multivariate (season)": [
        'energy (kw 15min)',
        'season idx'
    ]
}

# Input Report Simulation
IRS = []
for key in _.keys():
    IRS.append(
        LEARN_INFO(name=key, 
                   columns=_[key], 
                   is_contain_cluster_label=False),
    )
    
# Input Report Simulation
for key in _.keys():
    IRS.append(
        LEARN_INFO(name="{} / with cluster".format(key), 
                   columns=_[key], 
                   is_contain_cluster_label=True),
    )
    
# Training Model Array 
TMA = []

is_switch = True

for _ in IRS:
    bm = BasicModel(name=_.name,
                   columns=_.columns,
                   is_contain_cluster_label=_.is_label,
                   is_switch=is_switch)
    
    bm.set_window()
    bm.set_model()
    print(bm)
    bm.training(epochs=50)
    
    bm.set_predict(is_reshape=True)
    bm.set_predict(is_reshape=True, is_val_datas=True)
    
    TMA.append(bm)
    
test_evaluate_df = pd.DataFrame();
val_evaluate_df = pd.DataFrame();

for _ in TMA:
    test_evaluate_df = test_evaluate_df.append(_.statistic(), ignore_index=True)
    val_evaluate_df = val_evaluate_df.append(_.statistic(is_val_datas=True), ignore_index=True)
    
test_evaluate_df.index = [_.name for _ in TMA]
val_evaluate_df.index = [_.name for _ in TMA]
# Out:
# ###### [Notice] (multivariate (season) / with cluster) set predict (validation) info start ######
#
# 0 / 171
# 50 / 171
# 100 / 171
# 150 / 171
# 171 / 171 complete.
#
# ###### [Notice] set predict info success ######

# %%
back_up = {
    "test": test_evaluate_df.copy(),
    "val": val_evaluate_df.copy()
}

# %%
back_up['test']
# Out:
#                                             cos        ecv       mae  \
# univariate                             0.954899  84.311820  0.172939
# multivariate (week)                    0.956483  84.849788  0.174353
# multivariate (year)                    0.938716  78.825252  0.217726
# multivariate (weather)                 0.953719  83.869852  0.175297
# multivariate (avg ta)                  0.895876  61.530616  0.307801
# multivariate (avg rhm)                 0.952676  83.474784  0.179619
# multivariate (season)                  0.947340  80.810091  0.191199
# univariate / with cluster              0.956453  83.156599  0.187102
# multivariate (week) / with cluster     0.957966  83.560415  0.188846
# multivariate (year) / with cluster     0.941283  79.665320  0.213260
# multivariate (weather) / with cluster  0.953683  81.889886  0.192750
# multivariate (avg ta) / with cluster   0.932040  76.627138  0.226631
# multivariate (avg rhm) / with cluster  0.952546  81.742504  0.196845
# multivariate (season) / with cluster   0.953529  83.486532  0.179745
#
#                                        mean dis  mean sim       mse  \
# univariate                             1.073646  0.944215  0.063649
# multivariate (week)                    1.052740  0.945654  0.061466
# multivariate (year)                    1.266031  0.928042  0.085908
# multivariate (weather)                 1.086643  0.943109  0.065442
# multivariate (avg ta)                  1.727283  0.899254  0.156075
# multivariate (avg rhm)                 1.103377  0.942716  0.067045
# multivariate (season)                  1.193451  0.937593  0.077856
# univariate / with cluster              1.109389  0.947911  0.068336
# multivariate (week) / with cluster     1.094889  0.949415  0.066697
# multivariate (year) / with cluster     1.241304  0.936007  0.082500
# multivariate (weather) / with cluster  1.141339  0.946006  0.073475
# multivariate (avg ta) / with cluster   1.324181  0.926044  0.094826
# multivariate (avg rhm) / with cluster  1.158903  0.943606  0.074073
# multivariate (season) / with cluster   1.097593  0.945057  0.066997
#
#                                                tss         wss
# univariate                             1456.910039  228.562668
# multivariate (week)                    1456.910039  220.724953
# multivariate (year)                    1456.910039  308.497031
# multivariate (weather)                 1456.910039  235.001742
# multivariate (avg ta)                  1456.910039  560.464315
# multivariate (avg rhm)                 1456.910039  240.757538
# multivariate (season)                  1456.910039  279.579708
# univariate / with cluster              1456.910039  245.393201
# multivariate (week) / with cluster     1456.910039  239.509970
# multivariate (year) / with cluster     1456.910039  296.258001
# multivariate (weather) / with cluster  1456.910039  263.848064
# multivariate (avg ta) / with cluster   1456.910039  340.521569
# multivariate (avg rhm) / with cluster  1456.910039  265.995291
# multivariate (season) / with cluster   1456.910039  240.586370

# %%
back_up['val']
# Out:
#                                             cos        ecv       mae  \
# univariate                             0.940613  77.732287  0.195294
# multivariate (week)                    0.941283  78.126331  0.203783
# multivariate (year)                    0.936213  75.802508  0.230030
# multivariate (weather)                 0.941467  78.093955  0.193494
# multivariate (avg ta)                  0.930756  74.281461  0.218533
# multivariate (avg rhm)                 0.939421  77.469934  0.206596
# multivariate (season)                  0.938714  75.516103  0.206518
# univariate / with cluster              0.952216  81.866564  0.193192
# multivariate (week) / with cluster     0.952376  81.990119  0.198597
# multivariate (year) / with cluster     0.938638  76.894403  0.230235
# multivariate (weather) / with cluster  0.950638  81.088174  0.201076
# multivariate (avg ta) / with cluster   0.949052  80.622012  0.202431
# multivariate (avg rhm) / with cluster  0.952164  81.207205  0.206431
# multivariate (season) / with cluster   0.944276  79.213586  0.194132
#
#                                        mean dis  mean sim       mse  \
# univariate                             1.298467  0.921584  0.097006
# multivariate (week)                    1.285083  0.922431  0.095289
# multivariate (year)                    1.398180  0.917717  0.105412
# multivariate (weather)                 1.287780  0.922583  0.095430
# multivariate (avg ta)                  1.408482  0.911029  0.112038
# multivariate (avg rhm)                 1.324211  0.921406  0.098148
# multivariate (season)                  1.371466  0.917679  0.106660
# univariate / with cluster              1.200300  0.935111  0.078995
# multivariate (week) / with cluster     1.191598  0.935341  0.078457
# multivariate (year) / with cluster     1.378038  0.920872  0.100656
# multivariate (weather) / with cluster  1.230153  0.934006  0.082386
# multivariate (avg ta) / with cluster   1.254005  0.930223  0.084417
# multivariate (avg rhm) / with cluster  1.236943  0.936409  0.081868
# multivariate (season) / with cluster   1.269944  0.927349  0.090552
#
#                                               tss         wss
# univariate                             832.494756  185.377542
# multivariate (week)                    832.494756  182.097146
# multivariate (year)                    832.494756  201.442853
# multivariate (weather)                 832.494756  182.366678
# multivariate (avg ta)                  832.494756  214.105492
# multivariate (avg rhm)                 832.494756  187.561621
# multivariate (season)                  832.494756  203.827160
# univariate / with cluster              832.494756  150.959902
# multivariate (week) / with cluster     832.494756  149.931318
# multivariate (year) / with cluster     832.494756  192.352887
# multivariate (weather) / with cluster  832.494756  157.439956
# multivariate (avg ta) / with cluster   832.494756  161.320738
# multivariate (avg rhm) / with cluster  832.494756  156.449033
# multivariate (season) / with cluster   832.494756  173.045806

# %%
test_evaluate_df
# Out:
#                                             cos        ecv       mae  \
# univariate                             0.940924  77.923750  0.194593
# multivariate (week)                    0.941568  78.206911  0.202043
# multivariate (year)                    0.907214  65.002491  0.319878
# multivariate (weather)                 0.941060  78.010981  0.196892
# multivariate (avg ta)                  0.931318  74.562605  0.214878
# multivariate (avg rhm)                 0.938816  77.251588  0.203873
# multivariate (season)                  0.936866  76.094239  0.199304
# univariate / with cluster              0.944550  78.925656  0.206045
# multivariate (week) / with cluster     0.947599  80.243023  0.206274
# multivariate (year) / with cluster     0.936608  76.005842  0.235793
# multivariate (weather) / with cluster  0.945267  79.259867  0.203818
# multivariate (avg ta) / with cluster   0.931613  74.547194  0.219576
# multivariate (avg rhm) / with cluster  0.943601  78.720127  0.210026
# multivariate (season) / with cluster   0.944277  79.205074  0.193587
#
#                                        mean dis  mean sim       mse  \
# univariate                             1.293681  0.922015  0.096171
# multivariate (week)                    1.281110  0.922363  0.094938
# multivariate (year)                    1.740764  0.884328  0.152461
# multivariate (weather)                 1.292780  0.922426  0.095791
# multivariate (avg ta)                  1.397268  0.911096  0.110814
# multivariate (avg rhm)                 1.325308  0.920069  0.099100
# multivariate (season)                  1.339589  0.917343  0.104141
# univariate / with cluster              1.288306  0.926384  0.091807
# multivariate (week) / with cluster     1.247190  0.929349  0.086068
# multivariate (year) / with cluster     1.406426  0.918721  0.104526
# multivariate (weather) / with cluster  1.274591  0.927423  0.090351
# multivariate (avg ta) / with cluster   1.407362  0.913835  0.110881
# multivariate (avg rhm) / with cluster  1.299826  0.927465  0.092702
# multivariate (season) / with cluster   1.268367  0.926053  0.090590
#
#                                               tss         wss
# univariate                             832.494756  183.783627
# multivariate (week)                    832.494756  181.426323
# multivariate (year)                    832.494756  291.352430
# multivariate (weather)                 832.494756  183.057426
# multivariate (avg ta)                  832.494756  211.764982
# multivariate (avg rhm)                 832.494756  189.379336
# multivariate (season)                  832.494756  199.014210
# univariate / with cluster              832.494756  175.442807
# multivariate (week) / with cluster     832.494756  164.475794
# multivariate (year) / with cluster     832.494756  199.750108
# multivariate (weather) / with cluster  832.494756  172.660520
# multivariate (avg ta) / with cluster   832.494756  211.893276
# multivariate (avg rhm) / with cluster  832.494756  177.153828
# multivariate (season) / with cluster   832.494756  173.116665

# %%
val_evaluate_df
# Out:
#                                             cos        ecv       mae  \
# univariate                             0.954361  84.105663  0.173595
# multivariate (week)                    0.956638  84.879624  0.175521
# multivariate (year)                    0.922930  73.578492  0.253305
# multivariate (weather)                 0.953829  83.846760  0.176665
# multivariate (avg ta)                  0.902587  64.672570  0.288186
# multivariate (avg rhm)                 0.952804  83.541408  0.178646
# multivariate (season)                  0.949960  82.694905  0.179458
# univariate / with cluster              0.955619  82.762876  0.187815
# multivariate (week) / with cluster     0.957761  83.485131  0.187963
# multivariate (year) / with cluster     0.943717  80.453432  0.211677
# multivariate (weather) / with cluster  0.954842  82.801099  0.184644
# multivariate (avg ta) / with cluster   0.897189  62.384523  0.309738
# multivariate (avg rhm) / with cluster  0.954291  82.643799  0.191232
# multivariate (season) / with cluster   0.953923  83.716155  0.177139
#
#                                        mean dis  mean sim       mse  \
# univariate                             1.077627  0.944023  0.064485
# multivariate (week)                    1.052807  0.945503  0.061345
# multivariate (year)                    1.440655  0.907986  0.107195
# multivariate (weather)                 1.088906  0.943427  0.065536
# multivariate (avg ta)                  1.648506  0.902952  0.143327
# multivariate (avg rhm)                 1.101698  0.942390  0.066774
# multivariate (season)                  1.118635  0.941195  0.070209
# univariate / with cluster              1.123992  0.946074  0.069933
# multivariate (week) / with cluster     1.096698  0.948154  0.067003
# multivariate (year) / with cluster     1.229819  0.934389  0.079303
# multivariate (weather) / with cluster  1.113884  0.946212  0.069778
# multivariate (avg ta) / with cluster   1.717245  0.902652  0.152610
# multivariate (avg rhm) / with cluster  1.131154  0.944804  0.070416
# multivariate (season) / with cluster   1.087538  0.944814  0.066065
#
#                                                tss         wss
# univariate                             1456.910039  231.566189
# multivariate (week)                    1456.910039  220.290271
# multivariate (year)                    1456.910039  384.937598
# multivariate (weather)                 1456.910039  235.338180
# multivariate (avg ta)                  1456.910039  514.688873
# multivariate (avg rhm)                 1456.910039  239.786873
# multivariate (season)                  1456.910039  252.119668
# univariate / with cluster              1456.910039  251.129393
# multivariate (week) / with cluster     1456.910039  240.606788
# multivariate (year) / with cluster     1456.910039  284.775908
# multivariate (weather) / with cluster  1456.910039  250.572514
# multivariate (avg ta) / with cluster   1456.910039  548.023664
# multivariate (avg rhm) / with cluster  1456.910039  252.864228
# multivariate (season) / with cluster   1456.910039  237.240973

# %%
test_evaluate_df.sort_values(by=['ecv'], ascending=False)[:5]
# Out:
#                                             ecv       mae  mean dis  mean sim  \
# multivariate (week)                   84.758505  0.176430  1.056746  0.945356
# univariate                            84.120352  0.174280  1.079956  0.943997
# multivariate (weather)                84.056249  0.176009  1.082891  0.943889
# multivariate (avg rhm)                83.340644  0.180551  1.108665  0.942025
# multivariate (season) / with cluster  83.202664  0.179209  1.097820  0.945138
#
#                                            mse          tss         wss
# multivariate (week)                   0.061837  1456.910039  222.054877
# univariate                            0.064426  1456.910039  231.352189
# multivariate (weather)                0.064686  1456.910039  232.286115
# multivariate (avg rhm)                0.067589  1456.910039  242.711835
# multivariate (season) / with cluster  0.068149  1456.910039  244.722078

# %%
val_evaluate_df.sort_values(by=['mae'])[:5]
# Out:
#                                              ecv       mae  mean dis  \
# multivariate (season) / with cluster   79.063957  0.193860  1.271349
# multivariate (weather) / with cluster  81.407330  0.193963  1.213520
# univariate                             78.101904  0.196484  1.290971
# univariate / with cluster              81.720022  0.196917  1.208600
# multivariate (avg ta) / with cluster   80.400292  0.197137  1.252346
#
#                                        mean sim       mse         tss  \
# multivariate (season) / with cluster   0.926841  0.091204  832.494756
# multivariate (weather) / with cluster  0.933638  0.080996  832.494756
# univariate                             0.922425  0.095395  832.494756
# univariate / with cluster              0.935401  0.079634  832.494756
# multivariate (avg ta) / with cluster   0.929861  0.085383  832.494756
#
#                                               wss
# multivariate (season) / with cluster   174.291460
# multivariate (weather) / with cluster  154.783005
# univariate                             182.300503
# univariate / with cluster              152.179860
# multivariate (avg ta) / with cluster   163.166541

# %%
val_evaluate_df.sort_values(by=['mse'])[:5]
# Out:
#                                              ecv       mae  mean dis  \
# univariate / with cluster              81.720022  0.196917  1.208600
# multivariate (weather) / with cluster  81.407330  0.193963  1.213520
# multivariate (week) / with cluster     81.307967  0.204247  1.219275
# multivariate (avg ta) / with cluster   80.400292  0.197137  1.252346
# multivariate (avg rhm) / with cluster  79.989814  0.211545  1.271581
#
#                                        mean sim       mse         tss  \
# univariate / with cluster              0.935401  0.079634  832.494756
# multivariate (weather) / with cluster  0.933638  0.080996  832.494756
# multivariate (week) / with cluster     0.932674  0.081429  832.494756
# multivariate (avg ta) / with cluster   0.929861  0.085383  832.494756
# multivariate (avg rhm) / with cluster  0.932726  0.087171  832.494756
#
#                                               wss
# univariate / with cluster              152.179860
# multivariate (weather) / with cluster  154.783005
# multivariate (week) / with cluster     155.610196
# multivariate (avg ta) / with cluster   163.166541
# multivariate (avg rhm) / with cluster  166.583747

# %%
val_evaluate_df.sort_values(by=['ecv'], ascending=False)[:5]
# Out:
#                                              ecv       mae  mean dis  \
# univariate / with cluster              81.720022  0.196917  1.208600
# multivariate (weather) / with cluster  81.407330  0.193963  1.213520
# multivariate (week) / with cluster     81.307967  0.204247  1.219275
# multivariate (avg ta) / with cluster   80.400292  0.197137  1.252346
# multivariate (avg rhm) / with cluster  79.989814  0.211545  1.271581
#
#                                        mean sim       mse         tss  \
# univariate / with cluster              0.935401  0.079634  832.494756
# multivariate (weather) / with cluster  0.933638  0.080996  832.494756
# multivariate (week) / with cluster     0.932674  0.081429  832.494756
# multivariate (avg ta) / with cluster   0.929861  0.085383  832.494756
# multivariate (avg rhm) / with cluster  0.932726  0.087171  832.494756
#
#                                               wss
# univariate / with cluster              152.179860
# multivariate (weather) / with cluster  154.783005
# multivariate (week) / with cluster     155.610196
# multivariate (avg ta) / with cluster   163.166541
# multivariate (avg rhm) / with cluster  166.583747
