# %%
import pandas as pd

# %%
test_result = pd.read_csv("./result/test_evaluate_result.csv")
test_result.set_index("Unnamed: 0", inplace=True)
test_result.index.name = "type"
val_result = pd.read_csv("./result/val_evaluate_result.csv")
val_result.set_index("Unnamed: 0", inplace=True)
val_result.index.name = "type"

# %%
test_result.sort_values(by=['mean sim'], ascending=False)[:10]
# Out:
#                                                           ecv       mae  \
# type
#  - energy (kw 15min) - week sin - week cos / wi...  83.349425  0.189170
#  - energy (kw 15min) - week sin - week cos - av...  83.426318  0.191627
#  - energy (kw 15min) / with cluster                 82.461186  0.191007
#  - energy (kw 15min) - week sin - week cos - we...  82.723412  0.190292
#  - energy (kw 15min) - week sin - week cos - we...  83.095846  0.192345
#  - energy (kw 15min) - week sin - week cos          84.776281  0.175979
#  - energy (kw 15min) - week sin - week cos - av...  84.373830  0.178002
#  - energy (kw 15min) - week sin - week cos - we...  84.726639  0.177485
#  - energy (kw 15min)                                84.237622  0.173896
#  - energy (kw 15min) - weather idx / with cluster   81.837514  0.191968
#
#                                                     mean dis  mean sim  \
# type
#  - energy (kw 15min) - week sin - week cos / wi...  1.097934  0.949895
# ...

# %%
val_result.sort_values(by=['mean sim'], ascending=False)[:10]
# Out:
#                                                           ecv       mae  \
# type
#  - energy (kw 15min) - weather idx / with cluster   82.364548  0.194552
#  - energy (kw 15min) - week sin - week cos / wi...  82.396769  0.194726
#  - energy (kw 15min) - week sin - week cos - av...  81.210724  0.198784
#  - energy (kw 15min) / with cluster                 81.432489  0.197487
#  - energy (kw 15min) - week sin - week cos - we...  81.974651  0.196879
#  - energy (kw 15min) - weather idx - avg rhm / ...  80.613117  0.207680
#  - energy (kw 15min) - avg rhm / with cluster       81.008731  0.203315
#  - energy (kw 15min) - week sin - week cos - av...  80.931717  0.208250
#  - energy (kw 15min) - week sin - week cos - we...  80.865781  0.199975
#  - energy (kw 15min) - avg ta - avg rhm / with ...  79.859605  0.204309
#
#                                                     mean dis  mean sim  \
# type
#  - energy (kw 15min) - weather idx / with cluster   1.191169  0.937535
# ...
