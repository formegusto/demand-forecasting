# %%
import pandas as pd

# %%
test_result = pd.read_csv("./result/test_evaluate_result.csv")
test_result.set_index("Unnamed: 0", inplace=True)
test_result.index.name = "type"
val_result = pd.read_csv("./result/val_evaluate_result.csv")
val_result.set_index("Unnamed: 0", inplace=True)
val_result.index.name = "type"

# %%
test_result
# Out:
#                                                           ecv       mae  \
# type
#  - energy (kw 15min)                                84.237622  0.173896
#  - energy (kw 15min) - week sin - week cos          84.776281  0.175979
#  - energy (kw 15min) - year sin - year cos          74.613345  0.247820
#  - energy (kw 15min) - season idx                   81.651486  0.183742
#  - energy (kw 15min) - weather idx                  83.761605  0.176026
# ...                                                       ...       ...
#  - energy (kw 15min) - week sin - week cos - ye...  80.470584  0.205497
#  - energy (kw 15min) - week sin - week cos - ye...  82.450476  0.194281
#  - energy (kw 15min) - week sin - week cos - ye...  81.299790  0.200563
#  - energy (kw 15min) - week sin - week cos - se...  79.524523  0.214335
#  - energy (kw 15min) - year sin - year cos - se...  79.319808  0.217274
#
#                                                     mean dis  mean sim  \
# type
#  - energy (kw 15min)                                1.075648  0.944393
#  - energy (kw 15min) - week sin - week cos          1.056818  0.945338
#  - energy (kw 15min) - year sin - year cos          1.406148  0.914254
#  - energy (kw 15min) - season idx                   1.156001  0.937725
#  - energy (kw 15min) - weather idx                  1.088257  0.943163
# ...                                                      ...       ...
#  - energy (kw 15min) - week sin - week cos - ye...  1.187860  0.938430
#  - energy (kw 15min) - week sin - week cos - ye...  1.136293  0.940821
#  - energy (kw 15min) - week sin - week cos - ye...  1.179198  0.939038
#  - energy (kw 15min) - week sin - week cos - se...  1.252208  0.927356
#  - energy (kw 15min) - year sin - year cos - se...  1.257911  0.934503
#
#                                                          mse          tss  \
# type
#  - energy (kw 15min)                                0.063950  1456.910039
#  - energy (kw 15min) - week sin - week cos          0.061764  1456.910039
#  - energy (kw 15min) - year sin - year cos          0.102997  1456.910039
#  - energy (kw 15min) - season idx                   0.074442  1456.910039
#  - energy (kw 15min) - weather idx                  0.065881  1456.910039
# ...                                                      ...          ...
#  - energy (kw 15min) - week sin - week cos - ye...  0.079233  1456.910039
#  - energy (kw 15min) - week sin - week cos - ye...  0.071200  1456.910039
#  - energy (kw 15min) - week sin - week cos - ye...  0.075869  1456.910039
#  - energy (kw 15min) - week sin - week cos - se...  0.083071  1456.910039
#  - energy (kw 15min) - year sin - year cos - se...  0.083902  1456.910039
#
#                                                            wss
# type
#  - energy (kw 15min)                                229.643666
#  - energy (kw 15min) - week sin - week cos          221.795892
#  - energy (kw 15min) - year sin - year cos          369.860724
#  - energy (kw 15min) - season idx                   267.321336
#  - energy (kw 15min) - weather idx                  236.578813
# ...                                                        ...
#  - energy (kw 15min) - week sin - week cos - ye...  284.526019
#  - energy (kw 15min) - week sin - week cos - ye...  255.680781
#  - energy (kw 15min) - week sin - week cos - ye...  272.445232
#  - energy (kw 15min) - week sin - week cos - se...  298.309282
#  - energy (kw 15min) - year sin - year cos - se...  301.291790
#
# [126 rows x 7 columns]

# %%
val_result
# Out:
#                                                           ecv       mae  \
# type
#  - energy (kw 15min)                                77.987186  0.195256
#  - energy (kw 15min) - week sin - week cos          78.039248  0.206187
#  - energy (kw 15min) - year sin - year cos          71.653514  0.269559
#  - energy (kw 15min) - season idx                   76.100846  0.199084
#  - energy (kw 15min) - weather idx                  78.204518  0.193023
# ...                                                       ...       ...
#  - energy (kw 15min) - week sin - week cos - ye...  75.994638  0.213190
#  - energy (kw 15min) - week sin - week cos - ye...  75.816236  0.215008
#  - energy (kw 15min) - week sin - week cos - ye...  76.533668  0.223995
#  - energy (kw 15min) - week sin - week cos - se...  78.317506  0.226583
#  - energy (kw 15min) - year sin - year cos - se...  75.990008  0.230683
#
#                                                     mean dis  mean sim  \
# type
#  - energy (kw 15min)                                1.291934  0.922191
#  - energy (kw 15min) - week sin - week cos          1.287920  0.922134
#  - energy (kw 15min) - year sin - year cos          1.547792  0.904476
#  - energy (kw 15min) - season idx                   1.341090  0.917815
#  - energy (kw 15min) - weather idx                  1.283462  0.923131
# ...                                                      ...       ...
#  - energy (kw 15min) - week sin - week cos - ye...  1.366238  0.918417
#  - energy (kw 15min) - week sin - week cos - ye...  1.372861  0.921859
#  - energy (kw 15min) - week sin - week cos - ye...  1.364214  0.921398
#  - energy (kw 15min) - week sin - week cos - se...  1.348980  0.925154
#  - energy (kw 15min) - year sin - year cos - se...  1.397589  0.918281
#
#                                                          mse         tss  \
# type
#  - energy (kw 15min)                                0.095895  832.494756
#  - energy (kw 15min) - week sin - week cos          0.095668  832.494756
#  - energy (kw 15min) - year sin - year cos          0.123487  832.494756
#  - energy (kw 15min) - season idx                   0.104113  832.494756
#  - energy (kw 15min) - weather idx                  0.094948  832.494756
# ...                                                      ...         ...
#  - energy (kw 15min) - week sin - week cos - ye...  0.104575  832.494756
#  - energy (kw 15min) - week sin - week cos - ye...  0.105352  832.494756
#  - energy (kw 15min) - week sin - week cos - ye...  0.102227  832.494756
#  - energy (kw 15min) - week sin - week cos - se...  0.094456  832.494756
#  - energy (kw 15min) - year sin - year cos - se...  0.104595  832.494756
#
#                                                            wss
# type
#  - energy (kw 15min)                                183.255525
#  - energy (kw 15min) - week sin - week cos          182.822105
#  - energy (kw 15min) - year sin - year cos          235.983012
#  - energy (kw 15min) - season idx                   198.959202
#  - energy (kw 15min) - weather idx                  181.446245
# ...                                                        ...
#  - energy (kw 15min) - week sin - week cos - ye...  199.843379
#  - energy (kw 15min) - week sin - week cos - ye...  201.328565
#  - energy (kw 15min) - week sin - week cos - ye...  195.355981
#  - energy (kw 15min) - week sin - week cos - se...  180.505626
#  - energy (kw 15min) - year sin - year cos - se...  199.881927
#
# [126 rows x 7 columns]
